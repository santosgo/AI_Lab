# %% [markdown]
# # ImageAI

# %% [markdown]
# #### Notebook to test ImageAI, a python library that lets programmers and software developers easily integrate state-of-the-art computer vision technologies into their existing and new applications, using just few lines of code.

# %% [markdown]
# #### 1. Install the following dependencies via pip:

# %%
#!pip3 install tensorflow==1.1.15

# %%
#!pip3 install opencv-python

# %%
#!pip3 install keras --upgrade

# %%
#!pip3 install imageai --upgrade

# %% [markdown]
# #### 2. Run the code for image detection

# %% [markdown]
# ##### Load the RetinaNet model

# %%
from imageai.Detection import ObjectDetection

detector = ObjectDetection()
detector.setModelTypeAsRetinaNet()
detector.setModelPath('resnet50_coco_best_v2.0.1.h5')
detector.loadModel()
# Out:
# tracking <tf.Variable 'Variable_10:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_11:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_12:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_13:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_14:0' shape=(9, 4) dtype=float32> anchors

# %% [markdown]
# ##### Detect with RetinaNet

# %%
detections = detector.detectObjectsFromImage(input_image="image.jpeg", output_image_path="imagenew.jpg")

for eachObject in detections:
    print(eachObject["name"] , " : " , eachObject["percentage_probability"] )
# Out:
# person  :  57.203930616378784
# person  :  52.57977843284607
# person  :  70.81096768379211
# person  :  76.99859142303467
# person  :  79.40077781677246
# bicycle  :  81.03842735290527
# person  :  83.6672306060791
# person  :  89.41188454627991
# truck  :  60.610371828079224
# person  :  69.65751647949219
# bus  :  97.92423844337463
# truck  :  83.94356966018677
# car  :  72.50491380691528

# %% [markdown]
# ##### Show picture with image detection

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
img = mpimg.imread('imagenew.jpg')
fig = plt.figure()
fig = plt.figure(figsize=(14, 14))
ax = fig.add_subplot(111)
plt.title('RetinaNet')
plt.imshow(img)

# %% [markdown]
# ##### Load and detect with Yolo v3

# %%
detector2 = ObjectDetection()
detector2.setModelTypeAsYOLOv3()
detector2.setModelPath("yolo.h5")
detector2.loadModel()

# %%
detections2 = detector2.detectObjectsFromImage(input_image="image.jpeg", output_image_path="imagenewyolo.jpg")
for eachObject in detections2:
    print(eachObject["name"] , " : " , eachObject["percentage_probability"] )
# Out:
# traffic light  :  58.99158716201782
# truck  :  90.76634645462036
# bus  :  96.3744580745697
# bus  :  99.83058571815491
# person  :  75.55826902389526
# person  :  89.55667018890381
# person  :  93.83638501167297
# person  :  99.00351762771606
# person  :  99.69896078109741

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 12 ,12
img2 = mpimg.imread('imagenewyolo.jpg')
fig, ax = plt.subplots(2,1)
plt.subplot(2,1,1)
plt.title('RetinaNet')
plt.imshow(img)
plt.subplot(2,1,2)
plt.title('Yolo v3')
plt.imshow(img2)
