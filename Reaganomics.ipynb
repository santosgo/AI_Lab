# %% [markdown]
# # Automatic information extraction with NER and Reaganomics

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
from spacy import displacy

# %%
with open('reaganomics.txt') as f:
    docr = nlp(f.read())

# %%
displacy.render(docr,style='ent',jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">REAGANOMICS</br>https://en.wikipedia.org/wiki/Reaganomics</br></br>Reaganomics (a portmanteau of [
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ronald
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ]
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reagan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and economics attributed to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paul Harvey)[1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ] refers to the economic policies promoted by
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ronald Reagan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  during
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the 1980s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . These policies are commonly associated with supply-side economics, referred to as trickle-down economics or voodoo economics by political opponents, and free-market economics by political advocates.</br></br>The
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     four
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  pillars of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reagan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 's economic policy were to reduce the growth of government spending, reduce the federal income tax and capital gains tax, reduce government regulation, and tighten the money supply in order to reduce inflation.[2]</br></br>The results of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reaganomics
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  are still debated. Supporters point to the end of stagflation, stronger GDP growth, and an entrepreneur revolution in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the decades
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  that followed.[3][4] Critics point to the widening income gap, an atmosphere of greed, and the national debt tripling in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eight years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  which ultimately reversed the post-
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World War II
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  trend of a shrinking national debt as percentage of GDP.[5][6]</br></br>HISTORICAL CONTEXT</br></br>Prior to the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reagan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  administration,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  economy experienced
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a decade
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of high unemployment and persistently high inflation (known as stagflation). Attacks on
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Keynesian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  economic orthodoxy as well as empirical economic models such as
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Phillips Curve
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  grew. Political pressure favored stimulus resulting in an expansion of the money supply. President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Richard Nixon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 's wage and price controls were phased out.[7] The federal oil reserves were created to ease any future short term shocks. President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jimmy Carter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  had begun phasing out price controls on petroleum while he created
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em;

# %%
moneyents = [ent for ent in docr.ents if ent.label_ == "MONEY"]

# %%
len(moneyents) # amount of money type entities in docr
# Out:
# 27

# %%
def showMoneyents(moneyent):
    for moneyent in moneyents:
        print(f'{moneyent.text:{30}} {moneyent.label_} {moneyent.start:{4}} {moneyent.end:{4}} {docr[moneyent.start-5:moneyent.end+5].text:{50}}')

# %%
showMoneyents(moneyents)
# Out:
# $150 billion                   MONEY  905  908 paid by business corporations by $150 billion over a five-year
# $267.1 billion                 MONEY 1276 1279 constant 2000 dollars) from $267.1 billion in 1980 (4.9%
# $393.1 billion                 MONEY 1294 1297 of public expenditure) to $393.1 billion in 1988 (5.8%
# $997 billion to $2.85          MONEY 1530 1536 raising the national debt from $997 billion to $2.85 trillion.[33] This led to
# $712 billion                   MONEY 1918 1921 the public debt rose from $712 billion in 1980 to $2.052
# $2.052 trillion                MONEY 1924 1927 712 billion in 1980 to $2.052 trillion in 1988, a roughly
# less than $10,000              MONEY 2257 2261 percentage of total households making less than $10,000 a year (in real
# over $75,000                   MONEY 2286 2289 the percentage of households making over $75,000 went from 20.2% to
# over $2 trillion               MONEY 2664 2668 Reagan’s presidency, an over $2 trillion increase. The compound annual
# 4,492                          MONEY 2770 2771 family income grew by $4,492 during the Reagan period,
# 1,270                          MONEY 2780 2781 , compared to a $1,270 increase during the preceding eight
# 4,708                          MONEY 2801 2802 mean personal income rose $4,708 by 1988.[61] Nominal household
# $599 billion                   MONEY 3040 3043 year federal receipts grew from $599 billion to $991 billion (
# $678 billion                   MONEY 3061 3064 year federal outlays grew from $678 billion to $1144 billion (
# approximately $111 billion     MONEY 3213 3217 baseline without the cuts, approximately $111 billion (in 1992 dollars)
# $599 billion                   MONEY 3472 3475 nominal tax receipts increased from $599 billion in 1981 to $1.032
# $1.032 trillion                MONEY 3478 3481 599 billion in 1981 to $1.032 trillion in 1990, an increase
# $1.5 trillion                  MONEY 3503 3506 tax receipts in 1990 were $1.5 trillion, an increase of 20
# $738 billion to $              MONEY 3567 3572 in nominal terms, from $738 billion to $2.1 trillion.[77] This led
# eight years.[82                MONEY 3776 3778 13.0% during the preceding eight years.[82] The S&P 500 Index
# 4,000                          MONEY 4170 4171 family income grew by $4,000 and during the eight Reagan
# almost $1,500                  MONEY 4182 4185 and experienced a loss of almost $1,500 in the post-Reagan
# $15 trillion                   MONEY 4408 4411 in size, producing a $15 trillion increase in American wealth.
# 1,000,000                      MONEY 4581 4582 (with incomes exceeding $1,000,000) received a tax break
# $712 billion                   MONEY 4783 4786 the public debt rose from $712 billion in 1980 to $2,052
# $2,052 billion                 MONEY 4789 4792 712 billion in 1980 to $2,052 billion in 1988, a three
# about $125 billion             MONEY 4873 4877 to an additional debt of about $125 billion. Third, greater enforcement

# %%
# Creating list of money NERs without stop words and extracting respective lemmas
moneyentsConn = [docr[ent.start-8:ent.end+8].as_doc() for ent in docr.ents if ent.label_=="MONEY"]
contextline = []
for doc in moneyentsConn:
    for token in doc:
        if not token.is_stop:
            contextline.append(token.lemma_)
    contextline.append('\t')

# %%
# Joining list in one string and then splitting by delimeter '\t'
contextline = ' '.join(map(str, contextline)).split('\t')

# %%
# Modifying showMoneyents function to include new contextlines
def showMoneyents(moneyent):
    for i,moneyent in enumerate(moneyents):
        print(f'{moneyent.text:{30}} {moneyent.label_:{5}} {moneyent.start:{4}} {moneyent.end:{5}} {contextline[i]:{50}}')

# %%
showMoneyents(moneyents)
# Out:
# $150 billion                   MONEY  905   908 trim taxis pay business corporation $ 150 billion - year period .
# $267.1 billion                 MONEY 1276  1279  rise ( constant 2000 dollar ) $ 267.1 billion 1980 ( 4.9 % gdp
# $393.1 billion                 MONEY 1294  1297  22.7 % public expenditure ) $ 393.1 billion 1988 ( 5.8 % gdp
# $997 billion to $2.85          MONEY 1530  1536  budget deficit , raise national debt $ 997 billion $ 2.85 trillion.[33 ] lead U.S. move
# $712 billion                   MONEY 1918  1921  dollar term , public debt rise $ 712 billion 1980 $ 2.052 trillion 1988
# $2.052 trillion                MONEY 1924  1927  rise $ 712 billion 1980 $ 2.052 trillion 1988 , roughly - fold
# less than $10,000              MONEY 2257  2261  household , percentage total household make $ 10,000 year ( real 2007 dollar )
# over $75,000                   MONEY 2286  2289  1988 percentage household make $ 75,000 go 20.2 % 25.7 %
# over $2 trillion               MONEY 2664  2668  - Reagan presidency , $ 2 trillion increase . compound annual growth rate
# 4,492                          MONEY 2770  2771  ] real median family income grow $ 4,492 Reagan period , compare
# 1,270                          MONEY 2780  2781  Reagan period , compare $ 1,270 increase precede years.[60 ]
# 4,708                          MONEY 2801  2802  1980 , real mean personal income rise $ 4,708 1988.[61 ] Nominal household net worth increase
# $599 billion                   MONEY 3040  3043  administration , fiscal year federal receipt grow $ 599 billion $ 991 billion ( increase
# $678 billion                   MONEY 3061  3064  ) fiscal year federal outlay grow $ 678 billion $ 1144 billion ( increase
# approximately $111 billion     MONEY 3213  3217  relative baseline cut , approximately $ 111 billion ( 1992 dollar ) average
# $599 billion                   MONEY 3472  3475  accounting indicate nominal tax receipt increase $ 599 billion 1981 $ 1.032 trillion 1990
# $1.032 trillion                MONEY 3478  3481  increase $ 599 billion 1981 $ 1.032 trillion 1990 , increase 72 %
# $1.5 trillion                  MONEY 3503  3506  dollar , tax receipt 1990 $ 1.5 trillion , increase 20 % inflation.[76
# $738 billion to $              MONEY 3567  3572  public nearly triple nominal term , $ 738 billion $ 2.1 trillion.[77 ] lead U.S.
# eight years.[82                MONEY 3776  3778  , compare 13.0 % precede years.[82 ] S&P 500 Index increase 113.3 %
# 4,000                          MONEY 4170  4171  real median family income grow $ 4,000 Reagan year experience
# almost $1,500                  MONEY 4182  4185  Reagan year experience loss $ 1,500 post - reagan year . interest
# $15 trillion                   MONEY 4408  4411  size , produce $ 15 trillion increase american wealth . consumer investor
# 1,000,000                      MONEY 4581  4582  high income earner ( income exceed $ 1,000,000 ) receive tax break , restore
# $712 billion                   MONEY 4783  4786  dollar term , public debt rise $ 712 billion 1980 $ 2,052 billion 1988
# $2,052 billion                 MONEY 4789  4792  rise $ 712 billion 1980 $ 2,052 billion 1988 , - fold increase.[25
# about $125 billion             MONEY 4873  4877  loan problem lead additional debt $ 125 billion . , great enforcement U.S. trade

# %%
moneysents = []
for moneyent in moneyents:
    for sent in docr.sents:
        if sent.start < moneyent.start and sent.end > moneyent.end:
            moneysents.append(sent)

# %%
print(*moneysents,sep='\n\n')
# Out:
# This act slashed estate taxes and trimmed taxes paid by business corporations by $150 billion over a five-year period.
#
# Reagan significantly increased public expenditures, primarily the Department of Defense, which rose (in constant 2000 dollars) from $267.1 billion in 1980 (4.9% of GDP and 22.7% of public expenditure) to $393.1 billion in 1988 (5.8% of GDP and 27.3% of public expenditure); most of those years military spending was about 6% of GDP, exceeding this number in 4 different years.
#
# Reagan significantly increased public expenditures, primarily the Department of Defense, which rose (in constant 2000 dollars) from $267.1 billion in 1980 (4.9% of GDP and 22.7% of public expenditure) to $393.1 billion in 1988 (5.8% of GDP and 27.3% of public expenditure); most of those years military spending was about 6% of GDP, exceeding this number in 4 different years.
#
# As a short-run strategy to reduce inflation and lower nominal interest rates, the U.S. borrowed both domestically and abroad to cover the Federal budget deficits, raising the national debt from $997 billion to $2.85 trillion.[33]
#
# In dollar terms, the public debt rose from $712 billion in 1980 to $2.052 trillion in 1988, a roughly three-fold increase.[25]:143 The unemployment rate rose from 7% in 1980 to 11% in 1982, then declined to 5% in 1988.
#
# In dollar terms, the public debt rose from $712 billion in 1980 to $2.052 trillion in 1988, a roughly three-fold increase.[25]:143 The unemployment rate rose from 7% in 1980 to 11% in 1982, then declined to 5% in 1988.
#
# In terms of American households, the percentage of total households making less than $10,000 a year (in real 2007 dollars) shrank from 8.8% in 1980 to 8.3% in 1988 while the percentage of households making over $75,000 went from 20.2% to 25.7% during that period, both signs of progress.[51]
#
# Employment and wages
#
#
#
# In terms of American households, the percentage of total households making less than $10,000 a year (in real 2007 dollars) shrank from 8.8% in 1980 to 8.3% in 1988 while the percentage of households making over $75,000 went from 20.2% to 25.7% during that period, both signs of progress.[51]
#
# Employment and wages
#
#
#
# Real GDP grew over one-third during Reagan’s presidency, an over $2 trillion increase.
#
# ] Real median family income grew by $4,492 during the Reagan period, compared to a $1,270 increase during the preceding eight years.[60]
#
# ] Real median family income grew by $4,492 during the Reagan period, compared to a $1,270 increase during the preceding eight years.[60]
#
# After declining from 1974 through 1980, real mean personal income rose $4,708 by 1988.[61] Nominal household net worth increased by a CAGR of 8.4%, compared to 9.3% during the preceding eight years.[62]
#
#
#
# Federal income tax and payroll tax levels
#
# During the Reagan administration, fiscal year federal receipts grew from $599 billion to $991 billion (an increase of 65%)
#
# while fiscal year federal outlays grew from $678 billion to $1144 billion (an increase of 69%).[68][69]
#
# According to a 2003 Treasury study, the tax cuts in the Economic Recovery Tax Act of 1981 resulted in a significant decline in revenue relative to a baseline without the cuts, approximately $111 billion (in 1992 dollars) on average during the first four years after implementation or nearly 3% GDP annually.[71][72]
#
# An accounting indicated nominal tax receipts increased from $599 billion in 1981 to $1.032 trillion in 1990, an increase of 72% in current dollars.
#
# An accounting indicated nominal tax receipts increased from $599 billion in 1981 to $1.032 trillion in 1990, an increase of 72% in current dollars.
#
# In 2005 dollars, the tax receipts in 1990 were $1.5 trillion, an increase of 20% above inflation.[76]
#
#
#
# During Reagan's presidency, the federal debt held by the public nearly tripled in nominal terms, from $738 billion to $2.1 trillion.[77]
#
# Nominal after-tax corporate profits grew at a compound annual growth rate of 3.0% during Reagan's eight years, compared to 13.0% during the preceding eight years.[82]
#
# The study asserted that real median family income grew by $4,000 and during the eight Reagan years and experienced a loss of almost $1,500 in the post-Reagan years.
#
# The study asserted that real median family income grew by $4,000 and during the eight Reagan years and experienced a loss of almost $1,500 in the post-Reagan years.
#
# He also claims that the American economy grew by more than a third in size, producing a $15 trillion increase in American wealth.
#
# The highest income earners (with incomes exceeding $1,000,000) received a tax break, restoring a flatter tax system.[98]
#
# In dollar terms, the public debt rose from $712 billion in 1980 to $2,052 billion in 1988, a three-fold increase.[25] Krugman argued in June 2012 that Reagan's policies were consistent with Keynesian stimulus theories, pointing to the significant increase in per-capita spending under Reagan.[103]
#
#
#
# In dollar terms, the public debt rose from $712 billion in 1980 to $2,052 billion in 1988, a three-fold increase.[25] Krugman argued in June 2012 that Reagan's policies were consistent with Keynesian stimulus theories, pointing to the significant increase in per-capita spending under Reagan.[103]
#
#
#
# Second, the savings and loan problem led to an additional debt of about $125 billion.

# %%
# Modifying showMoneyents function to include related sentences
def showMoneyents(moneyent):
    for i,moneyent in enumerate(moneyents):
        print(f'{moneyent.text:{30}} {moneyent.label_:{5}} {moneyent.start:{4}} {moneyent.end:{5}} \n{moneysents[i]} \n')

# %%
showMoneyents(moneyents)
# Out:
# $150 billion                   MONEY  905   908
# This act slashed estate taxes and trimmed taxes paid by business corporations by $150 billion over a five-year period.
#
# $267.1 billion                 MONEY 1276  1279
# Reagan significantly increased public expenditures, primarily the Department of Defense, which rose (in constant 2000 dollars) from $267.1 billion in 1980 (4.9% of GDP and 22.7% of public expenditure) to $393.1 billion in 1988 (5.8% of GDP and 27.3% of public expenditure); most of those years military spending was about 6% of GDP, exceeding this number in 4 different years.
#
# $393.1 billion                 MONEY 1294  1297
# Reagan significantly increased public expenditures, primarily the Department of Defense, which rose (in constant 2000 dollars) from $267.1 billion in 1980 (4.9% of GDP and 22.7% of public expenditure) to $393.1 billion in 1988 (5.8% of GDP and 27.3% of public expenditure); most of those years military spending was about 6% of GDP, exceeding this number in 4 different years.
#
# $997 billion to $2.85          MONEY 1530  1536
# As a short-run strategy to reduce inflation and lower nominal interest rates, the U.S. borrowed both domestically and abroad to cover the Federal budget deficits, raising the national debt from $997 billion to $2.85 trillion.[33]
#
# $712 billion                   MONEY 1918  1921
# In dollar terms, the public debt rose from $712 billion in 1980 to $2.052 trillion in 1988, a roughly three-fold increase.[25]:143 The unemployment rate rose from 7% in 1980 to 11% in 1982, then declined to 5% in 1988.
#
# $2.052 trillion                MONEY 1924  1927
# In dollar terms, the public debt rose from $712 billion in 1980 to $2.052 trillion in 1988, a roughly three-fold increase.[25]:143 The unemployment rate rose from 7% in 1980 to 11% in 1982, then declined to 5% in 1988.
#
# less than $10,000              MONEY 2257  2261
# In terms of American households, the percentage of total households making less than $10,000 a year (in real 2007 dollars) shrank from 8.8% in 1980 to 8.3% in 1988 while the percentage of households making over $75,000 went from 20.2% to 25.7% during that period, both signs of progress.[51]
#
# Employment and wages
#
#
#
# over $75,000                   MONEY 2286  2289
# In terms of American households, the percentage of total households making less than $10,000 a year (in real 2007 dollars) shrank from 8.8% in 1980 to 8.3% in 1988 while the percentage of households making over $75,000 went from 20.2% to 25.7% during that period, both signs of progress.[51]
#
# Employment and wages
#
#
#
# over $2 trillion               MONEY 2664  2668
# Real GDP grew over one-third during Reagan’s presidency, an over $2 trillion increase.
#
# 4,492                          MONEY 2770  2771
# ] Real median family income grew by $4,492 during the Reagan period, compared to a $1,270 increase during the preceding eight years.[60]
#
# 1,270                          MONEY 2780  2781
# ] Real median family income grew by $4,492 during the Reagan period, compared to a $1,270 increase during the preceding eight years.[60]
#
# 4,708                          MONEY 2801  2802
# After declining from 1974 through 1980, real mean personal income rose $4,708 by 1988.[61] Nominal household net worth increased by a CAGR of 8.4%, compared to 9.3% during the preceding eight years.[62]
#
#
#
# $599 billion                   MONEY 3040  3043
# Federal income tax and payroll tax levels
#
# During the Reagan administration, fiscal year federal receipts grew from $599 billion to $991 billion (an increase of 65%)
#
# $678 billion                   MONEY 3061  3064
# while fiscal year federal outlays grew from $678 billion to $1144 billion (an increase of 69%).[68][69]
#
# approximately $111 billion     MONEY 3213  3217
# According to a 2003 Treasury study, the tax cuts in the Economic Recovery Tax Act of 1981 resulted in a significant decline in revenue relative to a baseline without the cuts, approximately $111 billion (in 1992 dollars) on average during the first four years after implementation or nearly 3% GDP annually.[71][72]
#
# $599 billion                   MONEY 3472  3475
# An accounting indicated nominal tax receipts increased from $599 billion in 1981 to $1.032 trillion in 1990, an increase of 72% in current dollars.
#
# $1.032 trillion                MONEY 3478  3481
# An accounting indicated nominal tax receipts increased from $599 billion in 1981 to $1.032 trillion in 1990, an increase of 72% in current dollars.
#
# $1.5 trillion                  MONEY 3503  3506
# In 2005 dollars, the tax receipts in 1990 were $1.5 trillion, an increase of 20% above inflation.[76]
#
#
#
# $738 billion to $              MONEY 3567  3572
# During Reagan's presidency, the federal debt held by the public nearly tripled in nominal terms, from $738 billion to $2.1 trillion.[77]
#
# eight years.[82                MONEY 3776  3778
# Nominal after-tax corporate profits grew at a compound annual growth rate of 3.0% during Reagan's eight years, compared to 13.0% during the preceding eight years.[82]
#
# 4,000                          MONEY 4170  4171
# The study asserted that real median family income grew by $4,000 and during the eight Reagan years and experienced a loss of almost $1,500 in the post-Reagan years.
#
# almost $1,500                  MONEY 4182  4185
# The study asserted that real median family income grew by $4,000 and during the eight Reagan years and experienced a loss of almost $1,500 in the post-Reagan years.
#
# $15 trillion                   MONEY 4408  4411
# He also claims that the American economy grew by more than a third in size, producing a $15 trillion increase in American wealth.
#
# 1,000,000                      MONEY 4581  4582
# The highest income earners (with incomes exceeding $1,000,000) received a tax break, restoring a flatter tax system.[98]
#
# $712 billion                   MONEY 4783  4786
# In dollar terms, the public debt rose from $712 billion in 1980 to $2,052 billion in 1988, a three-fold increase.[25] Krugman argued in June 2012 that Reagan's policies were consistent with Keynesian stimulus theories, pointing to the significant increase in per-capita spending under Reagan.[103]
#
#
#
# $2,052 billion                 MONEY 4789  4792
# In dollar terms, the public debt rose from $712 billion in 1980 to $2,052 billion in 1988, a three-fold increase.[25] Krugman argued in June 2012 that Reagan's policies were consistent with Keynesian stimulus theories, pointing to the significant increase in per-capita spending under Reagan.[103]
#
#
#
# about $125 billion             MONEY 4873  4877
# Second, the savings and loan problem led to an additional debt of about $125 billion.
