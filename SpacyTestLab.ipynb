# %% [markdown]
# # SPACY TEST LAB

# %% [markdown]
# ### 1. Install Spacy

# %%
#!pip install spacy

# %%
#!python -m spacy download en

# %% [markdown]
# ### 2. Import spacy and download english package

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# ### 3. Tokens, entities, chunks

# %%
mystring = 'Apple to build a Hong Kong factory for $6 million related to paid invoice 324546786 from 12/12/2019.'

# %%
doc = nlp(mystring)

# %%
for token in doc:
    print(token.text, end=' | ')
# Out:
# Apple | to | build | a | Hong | Kong | factory | for | $ | 6 | million | related | to | paid | invoice | 324546786 | from | 12/12/2019 | . |

# %%
for entity in doc.ents:
    print(entity, entity.label_)
    print(str(spacy.explain(entity.label_)))
# Out:
# Apple ORG
# Companies, agencies, institutions, etc.
# Hong Kong GPE
# Countries, cities, states
# $6 million MONEY
# Monetary values, including unit
# 324546786 CARDINAL
# Numerals that do not fall under another type
# 12/12/2019 DATE
# Absolute or relative dates or periods

# %%
for chunk in doc.noun_chunks:
    print(chunk)
# Out:
# Apple
# a Hong Kong factory
# paid invoice

# %% [markdown]
# ### 4. Displacy

# %%
from spacy import displacy

# %%
displacy.render(doc, style='dep', jupyter=True, options={'distance':110}) # dep = syntactic dependency
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="5097ce347a1f4b85b2b0f99886702b1c-0" class="displacy" width="2030" height="412.0" direction="ltr" style="max-width: none; height: 412.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">build</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">Hong</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">Kong</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">factory</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">6</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">million</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1260">related</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1260">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1480">paid</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1480">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">invoice</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">324546786</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1920">12/12/2019.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1920">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5097ce347a1f4b85b2b0f99886702b1c-0-0" stroke-width="2px" d="M180,277.0 C180,222.0 250.0,222.0 250.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5097ce347a1f4b85b2b0f99886702b1c-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M180,279.0 L172,267.0 188,267.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5097ce347a1f4b85b2b0f99886702b1c-0-1" stroke-width="2px" d="M70,277.0 C70,167.0 255.0,167.0 255.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5097ce347a1f4b85b2b0f99886702b1c-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">relcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M255.0,279.0 L263.0,267.0 247.0,267.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5097ce347a1f4b85b2b0f99886702b1c-0-2" stroke-width="2px" d="M400,277.0 C400,112.0 700.0,112.0 700.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5097ce347a1f4b85b2b0f99886702b1c-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400,279.0 L392,267.0 408,267.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5097ce347a1f4b85b2b0f99886702b1c-0-3" stroke-width="2px" d="M510,277.0 C510,222.0 580.0,222.0 580.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5097ce347a1f4b85b2b0f99886702b1c-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M510,279.0 L502,267.0 518,267.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5097ce347a1f4b85b2b0f99886702b1c-0-4" stroke-width="2px" d="M620,277.0 C620,222.0 690.0,222.0 690.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5097ce347a1f4b85b2b0f99886702b1c-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M620,279.0 L612,267.0 628,267.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5097ce347a1f4b85b2b0f99886702b1c-0-5" stroke-width="2px" d="M290,277.0 C290,57.0 705.0,57.0 705.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5097ce347a1f4b85b2b0f9

# %%
displacy.render(doc, style='ent', jupyter=True) # ent = entity
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to build a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hong Kong
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  factory for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $6 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  related to paid invoice
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     324546786
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12/12/2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</div>

# %% [markdown]
# ### 5. Lemmatization and stop words

# %%
doc1 = nlp(u'I am a runner running in a race because I love to run since I ran today.')
def show_lemmas(text):
    for token in text:
        print(f'{token.text:{12}} {token.pos_:{6}} {token.lemma:<{22}} {token.lemma_}')
show_lemmas(doc1)
# Out:
# I            PRON   561228191312463089     -PRON-
# am           AUX    10382539506755952630   be
# a            DET    11901859001352538922   a
# runner       NOUN   12640964157389618806   runner
# running      VERB   12767647472892411841   run
# in           ADP    3002984154512732771    in
# a            DET    11901859001352538922   a
# race         NOUN   8048469955494714898    race
# because      SCONJ  16950148841647037698   because
# I            PRON   561228191312463089     -PRON-
# love         VERB   3702023516439754181    love
# to           PART   3791531372978436496    to
# run          VERB   12767647472892411841   run
# since        SCONJ  10066841407251338481   since
# I            PRON   561228191312463089     -PRON-
# ran          VERB   12767647472892411841   run
# today        NOUN   11042482332948150395   today
# .            PUNCT  12646065887601541794   .

# %%
print(nlp.Defaults.stop_words)
# Out:
# {'done', 'one', 'due', 'below', 'another', 'same', 'many', 'besides', '’ve', 'hereby', 'somewhere', 'hers', 'all', 'while', 'mostly', 'very', 'amongst', 'not', 'out', 'wherever', 'least', 'nobody', 'latter', 'either', 'until', 'using', 'ever', 'off', 'forty', 'almost', 'around', 'where', 'into', 'anyway', 'yourself', 'n’t', 'afterwards', "'s", 'are', 'therein', "'ll", 'being', 'of', 'third', 'itself', 'in', 'fifty', 'there', 'your', 'and', 'might', 'here', 'hundred', 'himself', 'ourselves', 'never', 'above', 'mine', 'more', 'sometimes', 'throughout', 'whole', 'now', 'am', 'thereupon', 'moreover', 'sometime', 'made', "n't", 'upon', 'sixty', 'why', 'nine', "'ve", 'thru', 'each', 'up', 'various', '‘d', 'give', 'this', 'make', 'who', 'somehow', 'quite', 'yourselves', 'else', 'enough', 'empty', 'us', 'keep', 'our', 'towards', 'yours', 'among', 'a', 'become', 'under', 'thus', 'some', 'ours', 'him', 'myself', 'really', 'anywhere', '‘m', 'whenever', 'those', 'six', 'his', 'so', 'go', 'however', 'whom', 'it', 'eleven', 'thereby', 'after', 'something', 'indeed', 'often', 'its', 'together', 'ca', 'other', 'over', 'though', 'than', 'did', 'take', 'the', 'amount', 'whereafter', 'me', 'because', 'via', 'per', 'say', 'formerly', 'perhaps', 'serious', 'during', 'seem', 'too', '‘ve', 'hereafter', 'they', 'namely', 'had', 'thereafter', '‘re', 're', 'get', 'further', 'within', 'which', 'from', 'beforehand', 'since', 'therefore', 'by', 'how', 'next', 'please', 'her', 'whatever', 'for', 'back', 'was', 'but', 'cannot', 'someone', 'nowhere', 'name', 'along', 'neither', 'top', 'although', 'nothing', 'noone', 'with', '’s', '’m', 'that', 'five', 'hence', 'show', 'becoming', 'both', 'n‘t', 'used', 'such', 'if', 'what', 'been', 'fifteen', 'already', 'herein', 'call', 'then', 'everything', 'put', 'hereupon', 'whether', 'against', 'still', 'down', 'own', 'doing', 'anything', 'has', 'when', "'re", '’ll', 'should', 'seemed', 'rather', "'d", 'to', 'few', 'onto', 'you', 'others', 'at', 'themselves', 'through', 'eight', 'will', 'between', 'former', '‘s', 'be', 'front', 'he', 'anyhow', 'whereupon', 'would', 'their', 'them', 'unless', 'herself', 'whereby', 'were', 'does', 'side', '’re', 'most', 'whither', 'whose', "'m", 'thence', 'on', 'these', 'except', 'nevertheless', 'full', 'she', 'again', 'can', 'first', 'becomes', 'as', 'beyond', 'every', 'became', 'three', 'must', 'well', 'my', 'toward', 'across', 'ten', 'meanwhile', 'wherein', 'is', 'about', 'twenty', 'everyone', 'behind', 'latterly', 'nor', 'see', 'before', 'seems', 'elsewhere', 'even', 'none', 'beside', 'just', 'several', 'do', 'anyone', 'part', 'whence', 'last', 'an', 'always', 'less', 'twelve', 'only', 'without', 'whoever', '‘ll', 'two', 'could', 'otherwise', 'four', 'regarding', 'any', 'also', 'no', 'bottom', 'yet', 'seeming', 'we', 'may', 'have', 'once', 'everywhere', 'move', 'or', 'whereas', '’d', 'much', 'i', 'alone'}

# %% [markdown]
# ### 6. Phrase matching and vocabulary

# %%
with open('TextFiles/reaganomics.txt') as f:
    docr = nlp(f.read())
displacy.render(docr, style='ent', jupyter=True) # ent = entity
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">REAGANOMICS</br>https://en.wikipedia.org/wiki/Reaganomics</br></br>Reaganomics (a portmanteau of [
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ronald
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ]
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reagan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and economics attributed to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paul Harvey)[1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ] refers to the economic policies promoted by
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ronald Reagan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  during
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the 1980s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . These policies are commonly associated with supply-side economics, referred to as trickle-down economics or voodoo economics by political opponents, and free-market economics by political advocates.</br></br>The
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     four
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  pillars of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reagan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 's economic policy were to reduce the growth of government spending, reduce the federal income tax and capital gains tax, reduce government regulation, and tighten the money supply in order to reduce inflation.[2]</br></br>The results of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reaganomics
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  are still debated. Supporters point to the end of stagflation, stronger GDP growth, and an entrepreneur revolution in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the decades
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  that followed.[3][4] Critics point to the widening income gap, an atmosphere of greed, and the national debt tripling in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eight years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  which ultimately reversed the post-
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World War II
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  trend of a shrinking national debt as percentage of GDP.[5][6]</br></br>HISTORICAL CONTEXT</br></br>Prior to the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reagan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  administration,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  economy experienced
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a decade
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of high unemployment and persistently high inflation (known as stagflation). Attacks on
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Keynesian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  economic orthodoxy as well as empirical economic models such as
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Phillips Curve
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  grew. Political pressure favored stimulus resulting in an expansion of the money supply. President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Richard Nixon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 's wage and price controls were phased out.[7] The federal oil reserves were created to ease any future short term shocks. President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jimmy Carter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  had begun phasing out price controls on petroleum while he created
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em;
